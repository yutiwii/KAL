# %% [markdown]
# $
# A = \begin{bmatrix}
# 2 & 1 \\
# 1 & 2
# \end{bmatrix}
# $

# %%
import math
from IPython.display import display, Math

# Vektor [2, 1]
x = 2
y = 1

# Menghitung panjang vektor
panjang_vektor = math.sqrt(x**2 + y**2)

# Menampilkan bentuk LaTeX
display(Math(r'''
\|\vec{v}\| = \sqrt{2^2 + 1^2} = \sqrt{5}
'''))
# Out:
# $\displaystyle
# \|\vec{v}\| = \sqrt{2^2 + 1^2} = \sqrt{5}
# $

# %%
from IPython.display import display, Math

display(Math(r'''
a_1 =
\begin{bmatrix}
2 \\
1
\end{bmatrix}
'''))

display(Math(r'''
\|a_1\| =
\sqrt{2^2 + 1^2}
'''))

display(Math(r'''
= \sqrt{4 + 1}
'''))

display(Math(r'''
= \sqrt{5}
'''))
# Out:
# $\displaystyle
# a_1 =
# \begin{bmatrix}
# 2 \\
# 1
# \end{bmatrix}
# $
# $\displaystyle
# \|a_1\| =
# \sqrt{2^2 + 1^2}
# $
# $\displaystyle
# = \sqrt{4 + 1}
# $
# $\displaystyle
# = \sqrt{5}
# $

# %%
from IPython.display import display, Math

display(Math(r'''
a_2 =
\begin{bmatrix}
1 \\
2
\end{bmatrix}
'''))

display(Math(r'''
q_1 =
\frac{1}{\sqrt{5}}
\begin{bmatrix}
2 \\
1
\end{bmatrix}
=
\begin{bmatrix}
\frac{2}{\sqrt{5}} \\
\frac{1}{\sqrt{5}}
\end{bmatrix}
'''))

display(Math(r'''
v_2 = a_2 - (a_2 \cdot q_1)q_1
'''))

display(Math(r'''
a_2 \cdot q_1 =
(1)\left(\frac{2}{\sqrt{5}}\right)
+
(2)\left(\frac{1}{\sqrt{5}}\right)
=
\frac{4}{\sqrt{5}}
'''))

display(Math(r'''
v_2 =
\begin{bmatrix}
1 \\
2
\end{bmatrix}
-
\left(
\frac{4}{\sqrt{5}}
\right)
\begin{bmatrix}
\frac{2}{\sqrt{5}} \\
\frac{1}{\sqrt{5}}
\end{bmatrix}
'''))

display(Math(r'''
=
\begin{bmatrix}
1 \\
2
\end{bmatrix}
-
\begin{bmatrix}
\frac{8}{5} \\
\frac{4}{5}
\end{bmatrix}
=
\begin{bmatrix}
-\frac{3}{5} \\
\frac{6}{5}
\end{bmatrix}
'''))
# Out:
# $\displaystyle
# a_2 =
# \begin{bmatrix}
# 1 \\
# 2
# \end{bmatrix}
# $
# $\displaystyle
# q_1 =
# \frac{1}{\sqrt{5}}
# \begin{bmatrix}
# 2 \\
# 1
# \end{bmatrix}
# =
# \begin{bmatrix}
# \frac{2}{\sqrt{5}} \\
# \frac{1}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# v_2 = a_2 - (a_2 \cdot q_1)q_1
# $
# $\displaystyle
# a_2 \cdot q_1 =
# (1)\left(\frac{2}{\sqrt{5}}\right)
# +
# (2)\left(\frac{1}{\sqrt{5}}\right)
# =
# \frac{4}{\sqrt{5}}
# $
# $\displaystyle
# v_2 =
# \begin{bmatrix}
# 1 \\
# 2
# \end{bmatrix}
# -
# \left(
# \frac{4}{\sqrt{5}}
# \right)
# \begin{bmatrix}
# \frac{2}{\sqrt{5}} \\
# \frac{1}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# =
# \begin{bmatrix}
# 1 \\
# 2
# \end{bmatrix}
# -
# \begin{bmatrix}
# \frac{8}{5} \\
# \frac{4}{5}
# \end{bmatrix}
# =
# \begin{bmatrix}
# -\frac{3}{5} \\
# \frac{6}{5}
# \end{bmatrix}
# $

# %%
from IPython.display import display, Math

display(Math(r'''
v_2 =
\begin{bmatrix}
-\frac{3}{5} \\
\frac{6}{5}
\end{bmatrix}
'''))

display(Math(r'''
\|v_2\| =
\sqrt{
\left(-\frac{3}{5}\right)^2 +
\left(\frac{6}{5}\right)^2
}
'''))

display(Math(r'''
=
\sqrt{
\frac{9}{25} +
\frac{36}{25}
}
=
\sqrt{\frac{45}{25}}
=
\frac{3\sqrt{5}}{5}
'''))

display(Math(r'''
q_2 =
\frac{v_2}{\|v_2\|}
'''))

display(Math(r'''
=
\frac{
\begin{bmatrix}
-\frac{3}{5} \\
\frac{6}{5}
\end{bmatrix}
}{
\frac{3\sqrt{5}}{5}
}
=
\begin{bmatrix}
-\frac{1}{\sqrt{5}} \\
\frac{2}{\sqrt{5}}
\end{bmatrix}
'''))
# Out:
# $\displaystyle
# v_2 =
# \begin{bmatrix}
# -\frac{3}{5} \\
# \frac{6}{5}
# \end{bmatrix}
# $
# $\displaystyle
# \|v_2\| =
# \sqrt{
# \left(-\frac{3}{5}\right)^2 +
# \left(\frac{6}{5}\right)^2
# }
# $
# $\displaystyle
# =
# \sqrt{
# \frac{9}{25} +
# \frac{36}{25}
# }
# =
# \sqrt{\frac{45}{25}}
# =
# \frac{3\sqrt{5}}{5}
# $
# $\displaystyle
# q_2 =
# \frac{v_2}{\|v_2\|}
# $
# $\displaystyle
# =
# \frac{
# \begin{bmatrix}
# -\frac{3}{5} \\
# \frac{6}{5}
# \end{bmatrix}
# }{
# \frac{3\sqrt{5}}{5}
# }
# =
# \begin{bmatrix}
# -\frac{1}{\sqrt{5}} \\
# \frac{2}{\sqrt{5}}
# \end{bmatrix}
# $

# %%
from IPython.display import display, Math

display(Math(r'''
q_2 =
\begin{bmatrix}
-\frac{1}{\sqrt{5}} \\
\frac{2}{\sqrt{5}}
\end{bmatrix}
'''))

display(Math(r'''
\|q_2\| =
\sqrt{
\left(-\frac{1}{\sqrt{5}}\right)^2 +
\left(\frac{2}{\sqrt{5}}\right)^2
}
'''))

display(Math(r'''
=
\sqrt{
\frac{1}{5} +
\frac{4}{5}
}
'''))

display(Math(r'''
=
\sqrt{1}
= 1
'''))
# Out:
# $\displaystyle
# q_2 =
# \begin{bmatrix}
# -\frac{1}{\sqrt{5}} \\
# \frac{2}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# \|q_2\| =
# \sqrt{
# \left(-\frac{1}{\sqrt{5}}\right)^2 +
# \left(\frac{2}{\sqrt{5}}\right)^2
# }
# $
# $\displaystyle
# =
# \sqrt{
# \frac{1}{5} +
# \frac{4}{5}
# }
# $
# $\displaystyle
# =
# \sqrt{1}
# = 1
# $

# %%
from IPython.display import display, Math

# a1 . q1
display(Math(r'''
a_1 \cdot q_1 =
(2)\left(\frac{2}{\sqrt{5}}\right)
+
(1)\left(\frac{1}{\sqrt{5}}\right)
'''))

display(Math(r'''
=
\frac{4}{\sqrt{5}}
+
\frac{1}{\sqrt{5}}
=
\frac{5}{\sqrt{5}}
=
\sqrt{5}
'''))

# a2 . q1
display(Math(r'''
a_2 \cdot q_1 =
(1)\left(\frac{2}{\sqrt{5}}\right)
+
(2)\left(\frac{1}{\sqrt{5}}\right)
'''))

display(Math(r'''
=
\frac{2}{\sqrt{5}}
+
\frac{2}{\sqrt{5}}
=
\frac{4}{\sqrt{5}}
'''))

# a2 . q2
display(Math(r'''
a_2 \cdot q_2 =
(1)\left(-\frac{1}{\sqrt{5}}\right)
+
(2)\left(\frac{2}{\sqrt{5}}\right)
'''))

display(Math(r'''
=
-\frac{1}{\sqrt{5}}
+
\frac{4}{\sqrt{5}}
=
\frac{3}{\sqrt{5}}
'''))
# Out:
# $\displaystyle
# a_1 \cdot q_1 =
# (2)\left(\frac{2}{\sqrt{5}}\right)
# +
# (1)\left(\frac{1}{\sqrt{5}}\right)
# $
# $\displaystyle
# =
# \frac{4}{\sqrt{5}}
# +
# \frac{1}{\sqrt{5}}
# =
# \frac{5}{\sqrt{5}}
# =
# \sqrt{5}
# $
# $\displaystyle
# a_2 \cdot q_1 =
# (1)\left(\frac{2}{\sqrt{5}}\right)
# +
# (2)\left(\frac{1}{\sqrt{5}}\right)
# $
# $\displaystyle
# =
# \frac{2}{\sqrt{5}}
# +
# \frac{2}{\sqrt{5}}
# =
# \frac{4}{\sqrt{5}}
# $
# $\displaystyle
# a_2 \cdot q_2 =
# (1)\left(-\frac{1}{\sqrt{5}}\right)
# +
# (2)\left(\frac{2}{\sqrt{5}}\right)
# $
# $\displaystyle
# =
# -\frac{1}{\sqrt{5}}
# +
# \frac{4}{\sqrt{5}}
# =
# \frac{3}{\sqrt{5}}
# $

# %%
from IPython.display import display, Math

display(Math(r'''
Q =
\begin{bmatrix}
\frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
\frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
\end{bmatrix}
'''))

display(Math(r'''
R =
\begin{bmatrix}
\sqrt{5} & \frac{4}{\sqrt{5}} \\
0 & \frac{3}{\sqrt{5}}
\end{bmatrix}
'''))

display(Math(r'''
QR =
\begin{bmatrix}
\frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
\frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
\end{bmatrix}
\begin{bmatrix}
\sqrt{5} & \frac{4}{\sqrt{5}} \\
0 & \frac{3}{\sqrt{5}}
\end{bmatrix}
'''))

display(Math(r'''
=
\begin{bmatrix}
2 & 1 \\
1 & 2
\end{bmatrix}
'''))
# Out:
# $\displaystyle
# Q =
# \begin{bmatrix}
# \frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
# \frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# R =
# \begin{bmatrix}
# \sqrt{5} & \frac{4}{\sqrt{5}} \\
# 0 & \frac{3}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# QR =
# \begin{bmatrix}
# \frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
# \frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
# \end{bmatrix}
# \begin{bmatrix}
# \sqrt{5} & \frac{4}{\sqrt{5}} \\
# 0 & \frac{3}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# =
# \begin{bmatrix}
# 2 & 1 \\
# 1 & 2
# \end{bmatrix}
# $

# %%
from IPython.display import display, Math

# Matriks A
display(Math(r'''
A =
\begin{bmatrix}
2 & 1 \\
1 & 2
\end{bmatrix}
'''))

# q1
display(Math(r'''
q_1 =
\begin{bmatrix}
\frac{2}{\sqrt{5}} \\
\frac{1}{\sqrt{5}}
\end{bmatrix}
'''))

# q2
display(Math(r'''
q_2 =
\begin{bmatrix}
-\frac{1}{\sqrt{5}} \\
\frac{2}{\sqrt{5}}
\end{bmatrix}
'''))

# Matriks Q
display(Math(r'''
Q =
\begin{bmatrix}
\frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
\frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
\end{bmatrix}
'''))

# Perhitungan elemen R
display(Math(r'''
r_{11} = a_1 \cdot q_1 = \sqrt{5}
'''))

display(Math(r'''
r_{12} = a_2 \cdot q_1 = \frac{4}{\sqrt{5}}
'''))

display(Math(r'''
r_{22} = a_2 \cdot q_2 = \frac{3}{\sqrt{5}}
'''))

# Matriks R
display(Math(r'''
R =
\begin{bmatrix}
\sqrt{5} & \frac{4}{\sqrt{5}} \\
0 & \frac{3}{\sqrt{5}}
\end{bmatrix}
'''))

# Hasil akhir QR
display(Math(r'''
A = QR
'''))

display(Math(r'''
\begin{bmatrix}
2 & 1 \\
1 & 2
\end{bmatrix}
=
\begin{bmatrix}
\frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
\frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
\end{bmatrix}
\begin{bmatrix}
\sqrt{5} & \frac{4}{\sqrt{5}} \\
0 & \frac{3}{\sqrt{5}}
\end{bmatrix}
'''))
# Out:
# $\displaystyle
# A =
# \begin{bmatrix}
# 2 & 1 \\
# 1 & 2
# \end{bmatrix}
# $
# $\displaystyle
# q_1 =
# \begin{bmatrix}
# \frac{2}{\sqrt{5}} \\
# \frac{1}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# q_2 =
# \begin{bmatrix}
# -\frac{1}{\sqrt{5}} \\
# \frac{2}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# Q =
# \begin{bmatrix}
# \frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
# \frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# r_{11} = a_1 \cdot q_1 = \sqrt{5}
# $
# $\displaystyle
# r_{12} = a_2 \cdot q_1 = \frac{4}{\sqrt{5}}
# $
# $\displaystyle
# r_{22} = a_2 \cdot q_2 = \frac{3}{\sqrt{5}}
# $
# $\displaystyle
# R =
# \begin{bmatrix}
# \sqrt{5} & \frac{4}{\sqrt{5}} \\
# 0 & \frac{3}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# A = QR
# $
# $\displaystyle
# \begin{bmatrix}
# 2 & 1 \\
# 1 & 2
# \end{bmatrix}
# =
# \begin{bmatrix}
# \frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
# \frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
# \end{bmatrix}
# ...

# %%
from IPython.display import display, Math

display(Math(r'''
R =
\begin{bmatrix}
\sqrt{5} & \frac{4}{\sqrt{5}} \\
0 & \frac{3}{\sqrt{5}}
\end{bmatrix}
'''))

display(Math(r'''
Q =
\begin{bmatrix}
\frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
\frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
\end{bmatrix}
'''))

display(Math(r'''
RQ =
\begin{bmatrix}
\sqrt{5} & \frac{4}{\sqrt{5}} \\
0 & \frac{3}{\sqrt{5}}
\end{bmatrix}
\begin{bmatrix}
\frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
\frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
\end{bmatrix}
'''))

display(Math(r'''
=
\begin{bmatrix}
\frac{14}{5} & \frac{3}{5} \\
\frac{3}{5} & \frac{6}{5}
\end{bmatrix}
'''))
# Out:
# $\displaystyle
# R =
# \begin{bmatrix}
# \sqrt{5} & \frac{4}{\sqrt{5}} \\
# 0 & \frac{3}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# Q =
# \begin{bmatrix}
# \frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
# \frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# RQ =
# \begin{bmatrix}
# \sqrt{5} & \frac{4}{\sqrt{5}} \\
# 0 & \frac{3}{\sqrt{5}}
# \end{bmatrix}
# \begin{bmatrix}
# \frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}} \\
# \frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}
# \end{bmatrix}
# $
# $\displaystyle
# =
# \begin{bmatrix}
# \frac{14}{5} & \frac{3}{5} \\
# \frac{3}{5} & \frac{6}{5}
# \end{bmatrix}
# $

# %%
from IPython.display import display, Math

# ================= ITERASI 2 =================

display(Math(r'''
\textbf{Iterasi 2}
'''))

display(Math(r'''
A_2=
\begin{bmatrix}
2 & 1\\
1 & 2
\end{bmatrix}
'''))

display(Math(r'''
a_1=
\begin{bmatrix}
2\\
1
\end{bmatrix}
'''))

display(Math(r'''
\|a_1\|=
\sqrt{2^2+1^2}
=
\sqrt{5}
'''))

display(Math(r'''
q_1=
\frac{1}{\sqrt{5}}
\begin{bmatrix}
2\\
1
\end{bmatrix}
=
\begin{bmatrix}
\frac{2}{\sqrt5}\\
\frac{1}{\sqrt5}
\end{bmatrix}
'''))

display(Math(r'''
a_2=
\begin{bmatrix}
1\\
2
\end{bmatrix}
'''))

display(Math(r'''
a_2\cdot q_1=
(1)\left(\frac{2}{\sqrt5}\right)
+
(2)\left(\frac{1}{\sqrt5}\right)
=
\frac{4}{\sqrt5}
'''))

display(Math(r'''
v_2=
a_2-(a_2\cdot q_1)q_1
'''))

display(Math(r'''
=
\begin{bmatrix}
1\\
2
\end{bmatrix}
-
\frac{4}{\sqrt5}
\begin{bmatrix}
\frac{2}{\sqrt5}\\
\frac{1}{\sqrt5}
\end{bmatrix}
'''))

display(Math(r'''
=
\begin{bmatrix}
-\frac35\\
\frac65
\end{bmatrix}
'''))

display(Math(r'''
\|v_2\|=
\sqrt{
\left(-\frac35\right)^2+
\left(\frac65\right)^2
}
=
\frac{3\sqrt5}{5}
'''))

display(Math(r'''
q_2=
\frac{v_2}{\|v_2\|}
=
\begin{bmatrix}
-\frac1{\sqrt5}\\
\frac2{\sqrt5}
\end{bmatrix}
'''))

display(Math(r'''
Q_2=
\begin{bmatrix}
\frac2{\sqrt5} & -\frac1{\sqrt5}\\
\frac1{\sqrt5} & \frac2{\sqrt5}
\end{bmatrix}
'''))

display(Math(r'''
R_2=
\begin{bmatrix}
\sqrt5 & \frac4{\sqrt5}\\
0 & \frac3{\sqrt5}
\end{bmatrix}
'''))

display(Math(r'''
A_3=R_2Q_2
=
\begin{bmatrix}
\frac{14}{5} & \frac35\\
\frac35 & \frac65
\end{bmatrix}
'''))

# ================= ITERASI 3 =================

display(Math(r'''
\textbf{Iterasi 3}
'''))

display(Math(r'''
A_3=
\begin{bmatrix}
\frac{14}{5} & \frac35\\
\frac35 & \frac65
\end{bmatrix}
'''))

display(Math(r'''
a_1=
\begin{bmatrix}
\frac{14}{5}\\
\frac35
\end{bmatrix}
'''))

display(Math(r'''
\|a_1\|=
\sqrt{
\left(\frac{14}{5}\right)^2+
\left(\frac35\right)^2
}
=
\sqrt{\frac{41}{5}}
'''))

display(Math(r'''
q_1=
\begin{bmatrix}
\frac{14}{\sqrt{205}}\\
\frac3{\sqrt{205}}
\end{bmatrix}
'''))

display(Math(r'''
Q_3=
\begin{bmatrix}
\frac{14}{\sqrt{205}} & -\frac3{\sqrt{205}}\\
\frac3{\sqrt{205}} & \frac{14}{\sqrt{205}}
\end{bmatrix}
'''))

display(Math(r'''
R_3=
\begin{bmatrix}
\sqrt{\frac{41}{5}} & \frac{12}{\sqrt{205}}\\
0 & \frac{15}{\sqrt{205}}
\end{bmatrix}
'''))

display(Math(r'''
A_4=R_3Q_3
=
\begin{bmatrix}
\frac{82}{29} & \frac{15}{29}\\
\frac{15}{29} & \frac{34}{29}
\end{bmatrix}
'''))

# ================= ITERASI 4 =================


display(Math(r'''
\textbf{Iterasi 4}
'''))

# Matriks A4
display(Math(r'''
A_4=
\begin{bmatrix}
\frac{82}{29} & \frac{15}{29}\\
\frac{15}{29} & \frac{34}{29}
\end{bmatrix}
'''))

# a1
display(Math(r'''
a_1=
\begin{bmatrix}
\frac{82}{29}\\
\frac{15}{29}
\end{bmatrix}
'''))

# panjang a1
display(Math(r'''
\|a_1\|=
\sqrt{
\left(\frac{82}{29}\right)^2+
\left(\frac{15}{29}\right)^2
}
'''))

display(Math(r'''
=
\sqrt{
\frac{6724}{841}+
\frac{225}{841}
}
'''))

display(Math(r'''
=
\sqrt{
\frac{6949}{841}
}
'''))

display(Math(r'''
=
\frac{\sqrt{6949}}{29}
'''))

# q1
display(Math(r'''
q_1=
\frac{a_1}{\|a_1\|}
'''))

display(Math(r'''
=
\frac{
\begin{bmatrix}
\frac{82}{29}\\
\frac{15}{29}
\end{bmatrix}
}{
\frac{\sqrt{6949}}{29}
}
'''))

display(Math(r'''
=
\begin{bmatrix}
\frac{82}{\sqrt{6949}}\\
\frac{15}{\sqrt{6949}}
\end{bmatrix}
'''))

# a2
display(Math(r'''
a_2=
\begin{bmatrix}
\frac{15}{29}\\
\frac{34}{29}
\end{bmatrix}
'''))

# a2.q1
display(Math(r'''
a_2\cdot q_1=
\left(
\frac{15}{29}
\right)
\left(
\frac{82}{\sqrt{6949}}
\right)
+
\left(
\frac{34}{29}
\right)
\left(
\frac{15}{\sqrt{6949}}
\right)
'''))

display(Math(r'''
=
\frac{1230}{29\sqrt{6949}}
+
\frac{510}{29\sqrt{6949}}
'''))

display(Math(r'''
=
\frac{1740}{29\sqrt{6949}}
'''))

display(Math(r'''
=
\frac{60}{\sqrt{6949}}
'''))

# v2
display(Math(r'''
v_2=
a_2-(a_2\cdot q_1)q_1
'''))

display(Math(r'''
=
\begin{bmatrix}
\frac{15}{29}\\
\frac{34}{29}
\end{bmatrix}
-
\left(
\frac{60}{\sqrt{6949}}
\right)
\begin{bmatrix}
\frac{82}{\sqrt{6949}}\\
\frac{15}{\sqrt{6949}}
\end{bmatrix}
'''))

display(Math(r'''
=
\begin{bmatrix}
\frac{15}{29}\\
\frac{34}{29}
\end{bmatrix}
-
\begin{bmatrix}
\frac{4920}{6949}\\
\frac{900}{6949}
\end{bmatrix}
'''))

# q2
display(Math(r'''
q_2=
\begin{bmatrix}
-\frac{15}{\sqrt{6949}}\\
\frac{82}{\sqrt{6949}}
\end{bmatrix}
'''))

# Matriks Q
display(Math(r'''
Q_4=
\begin{bmatrix}
\frac{82}{\sqrt{6949}} & -\frac{15}{\sqrt{6949}}\\
\frac{15}{\sqrt{6949}} & \frac{82}{\sqrt{6949}}
\end{bmatrix}
'''))

# Matriks R
display(Math(r'''
R_4=
\begin{bmatrix}
\frac{\sqrt{6949}}{29} & \frac{60}{\sqrt{6949}}\\
0 & \frac{87}{\sqrt{6949}}
\end{bmatrix}
'''))

# A5
display(Math(r'''
A_5=R_4Q_4
'''))

display(Math(r'''
=
\begin{bmatrix}
\frac{478}{169} & \frac{75}{169}\\
\frac{75}{169} & \frac{198}{169}
\end{bmatrix}
'''))

# ================= ITERASI 5 =================

display(Math(r'''
\textbf{Iterasi 5}
'''))

display(Math(r'''
A_5=
\begin{bmatrix}
\frac{478}{169} & \frac{75}{169}\\
\frac{75}{169} & \frac{198}{169}
\end{bmatrix}
'''))

display(Math(r'''
a_1=
\begin{bmatrix}
\frac{478}{169}\\
\frac{75}{169}
\end{bmatrix}
'''))

display(Math(r'''
\|a_1\|=
\sqrt{
\left(\frac{478}{169}\right)^2+
\left(\frac{75}{169}\right)^2
}
=
\sqrt{\frac{233509}{28561}}
'''))

display(Math(r'''
q_1=
\begin{bmatrix}
\frac{478}{\sqrt{233509}}\\
\frac{75}{\sqrt{233509}}
\end{bmatrix}
'''))

display(Math(r'''
Q_5=
\begin{bmatrix}
\frac{478}{\sqrt{233509}} & -\frac{75}{\sqrt{233509}}\\
\frac{75}{\sqrt{233509}} & \frac{478}{\sqrt{233509}}
\end{bmatrix}
'''))

display(Math(r'''
R_5=
\begin{bmatrix}
\sqrt{\frac{233509}{28561}} & \frac{300}{\sqrt{233509}}\\
0 & \frac{507}{\sqrt{233509}}
\end{bmatrix}
'''))

display(Math(r'''
A_6=R_5Q_5
=
\begin{bmatrix}
\frac{2786}{985} & \frac{375}{985}\\
\frac{375}{985} & \frac{1154}{985}
\end{bmatrix}
'''))

# ================= ITERASI 6 =================

display(Math(r'''
\textbf{Iterasi 6}
'''))

display(Math(r'''
A_6=
\begin{bmatrix}
\frac{2786}{985} & \frac{375}{985}\\
\frac{375}{985} & \frac{1154}{985}
\end{bmatrix}
'''))

display(Math(r'''
a_1=
\begin{bmatrix}
\frac{2786}{985}\\
\frac{375}{985}
\end{bmatrix}
'''))

display(Math(r'''
\|a_1\|=
\sqrt{
\left(\frac{2786}{985}\right)^2+
\left(\frac{375}{985}\right)^2
}
=
\sqrt{\frac{7902821}{970225}}
'''))

display(Math(r'''
q_1=
\begin{bmatrix}
\frac{2786}{\sqrt{7902821}}\\
\frac{375}{\sqrt{7902821}}
\end{bmatrix}
'''))

display(Math(r'''
Q_6=
\begin{bmatrix}
\frac{2786}{\sqrt{7902821}} & -\frac{375}{\sqrt{7902821}}\\
\frac{375}{\sqrt{7902821}} & \frac{2786}{\sqrt{7902821}}
\end{bmatrix}
'''))

display(Math(r'''
R_6=
\begin{bmatrix}
\sqrt{\frac{7902821}{970225}} & \frac{1500}{\sqrt{7902821}}\\
0 & \frac{2955}{\sqrt{7902821}}
\end{bmatrix}
'''))

display(Math(r'''
A_7=R_6Q_6
=
\begin{bmatrix}
\frac{16238}{5741} & \frac{1875}{5741}\\
\frac{1875}{5741} & \frac{6726}{5741}
\end{bmatrix}
'''))

# ================= ITERASI 7 =================

from IPython.display import display, Math

# ================= ITERASI 7 =================

display(Math(r'''
\textbf{Iterasi 7}
'''))

display(Math(r'''
A_7=
\begin{bmatrix}
\frac{16238}{5741} & \frac{1875}{5741}\\
\frac{1875}{5741} & \frac{6726}{5741}
\end{bmatrix}
'''))

display(Math(r'''
a_1=
\begin{bmatrix}
\frac{16238}{5741}\\
\frac{1875}{5741}
\end{bmatrix}
'''))

display(Math(r'''
\|a_1\|=
\sqrt{
\left(\frac{16238}{5741}\right)^2+
\left(\frac{1875}{5741}\right)^2
}
=
\sqrt{\frac{267215269}{32959081}}
'''))

display(Math(r'''
q_1=
\begin{bmatrix}
\frac{16238}{\sqrt{267215269}}\\
\frac{1875}{\sqrt{267215269}}
\end{bmatrix}
'''))

display(Math(r'''
Q_7=
\begin{bmatrix}
\frac{16238}{\sqrt{267215269}} & -\frac{1875}{\sqrt{267215269}}\\
\frac{1875}{\sqrt{267215269}} & \frac{16238}{\sqrt{267215269}}
\end{bmatrix}
'''))

display(Math(r'''
R_7=
\begin{bmatrix}
\sqrt{\frac{267215269}{32959081}} & \frac{7500}{\sqrt{267215269}}\\
0 & \frac{17223}{\sqrt{267215269}}
\end{bmatrix}
'''))

display(Math(r'''
A_8=R_7Q_7
=
\begin{bmatrix}
\frac{94642}{33461} & \frac{9375}{33461}\\
\frac{9375}{33461} & \frac{39218}{33461}
\end{bmatrix}
'''))

# ================= ITERASI 8 =================

display(Math(r'''
\textbf{Iterasi 8}
'''))

display(Math(r'''
A_8=
\begin{bmatrix}
\frac{94642}{33461} & \frac{9375}{33461}\\
\frac{9375}{33461} & \frac{39218}{33461}
\end{bmatrix}
'''))

display(Math(r'''
a_1=
\begin{bmatrix}
\frac{94642}{33461}\\
\frac{9375}{33461}
\end{bmatrix}
'''))

display(Math(r'''
\|a_1\|=
\sqrt{
\left(\frac{94642}{33461}\right)^2+
\left(\frac{9375}{33461}\right)^2
}
=
\sqrt{\frac{9041461189}{1119632521}}
'''))

display(Math(r'''
q_1=
\begin{bmatrix}
\frac{94642}{\sqrt{9041461189}}\\
\frac{9375}{\sqrt{9041461189}}
\end{bmatrix}
'''))

display(Math(r'''
Q_8=
\begin{bmatrix}
\frac{94642}{\sqrt{9041461189}} & -\frac{9375}{\sqrt{9041461189}}\\
\frac{9375}{\sqrt{9041461189}} & \frac{94642}{\sqrt{9041461189}}
\end{bmatrix}
'''))

display(Math(r'''
R_8=
\begin{bmatrix}
\sqrt{\frac{9041461189}{1119632521}} & \frac{37500}{\sqrt{9041461189}}\\
0 & \frac{104017}{\sqrt{9041461189}}
\end{bmatrix}
'''))

display(Math(r'''
A_9=R_8Q_8
=
\begin{bmatrix}
\frac{551278}{195025} & \frac{46875}{195025}\\
\frac{46875}{195025} & \frac{228722}{195025}
\end{bmatrix}
'''))

# ================= ITERASI 9 =================

display(Math(r'''
\textbf{Iterasi 9}
'''))

display(Math(r'''
A_9=
\begin{bmatrix}
\frac{551278}{195025} & \frac{46875}{195025}\\
\frac{46875}{195025} & \frac{228722}{195025}
\end{bmatrix}
'''))

display(Math(r'''
a_1=
\begin{bmatrix}
\frac{551278}{195025}\\
\frac{46875}{195025}
\end{bmatrix}
'''))

display(Math(r'''
\|a_1\|=
\sqrt{
\left(\frac{551278}{195025}\right)^2+
\left(\frac{46875}{195025}\right)^2
}
=
\sqrt{\frac{306033745909}{38034750625}}
'''))

display(Math(r'''
q_1=
\begin{bmatrix}
\frac{551278}{\sqrt{306033745909}}\\
\frac{46875}{\sqrt{306033745909}}
\end{bmatrix}
'''))

display(Math(r'''
Q_9=
\begin{bmatrix}
\frac{551278}{\sqrt{306033745909}} & -\frac{46875}{\sqrt{306033745909}}\\
\frac{46875}{\sqrt{306033745909}} & \frac{551278}{\sqrt{306033745909}}
\end{bmatrix}
'''))

display(Math(r'''
R_9=
\begin{bmatrix}
\sqrt{\frac{306033745909}{38034750625}} & \frac{187500}{\sqrt{306033745909}}\\
0 & \frac{598153}{\sqrt{306033745909}}
\end{bmatrix}
'''))

display(Math(r'''
A_{10}=R_9Q_9
=
\begin{bmatrix}
\frac{3213574}{1136689} & \frac{234375}{1136689}\\
\frac{234375}{1136689} & \frac{1336058}{1136689}
\end{bmatrix}
'''))

# ================= ITERASI 10 =================

display(Math(r'''
\textbf{Iterasi 10}
'''))

display(Math(r'''
A_{10}=
\begin{bmatrix}
\frac{3213574}{1136689} & \frac{234375}{1136689}\\
\frac{234375}{1136689} & \frac{1336058}{1136689}
\end{bmatrix}
'''))

display(Math(r'''
a_1=
\begin{bmatrix}
\frac{3213574}{1136689}\\
\frac{234375}{1136689}
\end{bmatrix}
'''))

display(Math(r'''
\|a_1\|=
\sqrt{
\left(\frac{3213574}{1136689}\right)^2+
\left(\frac{234375}{1136689}\right)^2
}
=
\sqrt{\frac{10382949459401}{1292062722721}}
'''))

display(Math(r'''
q_1=
\begin{bmatrix}
\frac{3213574}{\sqrt{10382949459401}}\\
\frac{234375}{\sqrt{10382949459401}}
\end{bmatrix}
'''))

display(Math(r'''
Q_{10}=
\begin{bmatrix}
\frac{3213574}{\sqrt{10382949459401}} &
-\frac{234375}{\sqrt{10382949459401}}\\
\frac{234375}{\sqrt{10382949459401}} &
\frac{3213574}{\sqrt{10382949459401}}
\end{bmatrix}
'''))

display(Math(r'''
R_{10}=
\begin{bmatrix}
\sqrt{\frac{10382949459401}{1292062722721}} &
\frac{937500}{\sqrt{10382949459401}}\\
0 &
\frac{3447957}{\sqrt{10382949459401}}
\end{bmatrix}
'''))
# Out:
# $\displaystyle
# \textbf{Iterasi 2}
# $
# $\displaystyle
# A_2=
# \begin{bmatrix}
# 2 & 1\\
# 1 & 2
# \end{bmatrix}
# $
# $\displaystyle
# a_1=
# \begin{bmatrix}
# 2\\
# 1
# \end{bmatrix}
# $
# $\displaystyle
# \|a_1\|=
# \sqrt{2^2+1^2}
# =
# \sqrt{5}
# $
# $\displaystyle
# q_1=
# \frac{1}{\sqrt{5}}
# \begin{bmatrix}
# 2\\
# 1
# \end{bmatrix}
# =
# \begin{bmatrix}
# \frac{2}{\sqrt5}\\
# \frac{1}{\sqrt5}
# \end{bmatrix}
# $
# $\displaystyle
# a_2=
# \begin{bmatrix}
# 1\\
# 2
# \end{bmatrix}
# $
# $\displaystyle
# a_2\cdot q_1=
# (1)\left(\frac{2}{\sqrt5}\right)
# +
# (2)\left(\frac{1}{\sqrt5}\right)
# =
# \frac{4}{\sqrt5}
# $
# $\displaystyle
# v_2=
# a_2-(a_2\cdot q_1)q_1
# $
# $\displaystyle
# =
# \begin{bmatrix}
# 1\\
# 2
# \end{bmatrix}
# -
# \frac{4}{\sqrt5}
# \begin{bmatrix}
# \frac{2}{\sqrt5}\\
# \frac{1}{\sqrt5}
# \end{bmatrix}
# $
# $\displaystyle
# =
# \begin{bmatrix}
# -\frac35\\
# \frac65
# \end{bmatrix}
# $
# $\displaystyle
# \|v_2\|=
# \sqrt{
# \left(-\frac35\right)^2+
# ...
